# %%
# Import libraries
import pandas as pd

# %%
# Load data
train = pd.read_csv("Digit Recognizer/datasets/train.csv")

train.shape
# Out:
# (42000, 785)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Columns: 785 entries, label to pixel783
# dtypes: int64(785)
# memory usage: 251.5 MB
